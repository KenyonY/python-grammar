# %%
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y)
plt.legend([r'$\theta$'])
plt.title([
    'hahhah'
])
plt.show()
# Out:
# Text(0.5, 1.0, "['hahhah']")

# %%
plt.figure(figsize=(8,5))
fig,ax=plt.subplots()

x = np.linspace(0,10)
y = np.sin(x)
plt.plot(x,y)

xySize=15
fontproperties = 'Times New Roman'
plt.xlabel('Scattering Angle(deg)',fontproperties = 'Times New Roman',fontsize=xySize)
plt.ylabel('Frequency',fontproperties = 'Times New Roman',fontsize=xySize)



# plt.legend(['Numerical solution'],fontsize=15) # 
#**************************************************************************
tick_dict=dict(direction = 'in',top=1,right=1,length = 4,width =0.7, labelsize=12)
legend_dict = dict(family='Times New Roman',size=50)
plt.legend([r'$\theta_s(\theta_c)$'])

ax.tick_params(**tick_dict)

plt.show()
# Out:
# Text(0.5, 0, 'Scattering Angle(deg)')
# Text(0, 0.5, 'Frequency')

# %%
plt.xlabel('Scattering angle/(deg)',fontproperties = 'Times New Roman',fontsize=15)
plt.ylabel(' Relative refractive index ',fontproperties = 'Times New Roman',fontsize=15)
plt.yticks(fontproperties = 'Times New Roman', size = 15)
plt.xticks(fontproperties = 'Times New Roman', size = 15)
# Out:
# Text(0.5, 0, 'Scattering angle/(deg)')
# Text(0, 0.5, ' Relative refractive index ')
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text yticklabel objects>)
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)
