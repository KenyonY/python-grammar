# %%
import plotly
import plotly.graph_objects as go
import pandas as pd
import plotly.io as pio
pio.renderers.default = "browser"
import numpy as np

# %%
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')

# %%
x = np.linspace(0,1,100)
x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
z = np.linspace(0, 1, 100)

X, Y = np.meshgrid(x, y)
Z = np.sqrt(1-X**2 - Y**2)
# Out:
# /home/kunyuan/miniconda3/envs/tf2/lib/python3.6/site-packages/ipykernel_launcher.py:7: RuntimeWarning:
#
# invalid value encountered in sqrt

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = plt.axes(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
# Z = np.sin(R)
Z = (X+Y)/2
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, 
                       linewidth=0, antialiased=False)

# %%
X,

# %%
r, g, b = np.indices((17, 17, 17)) / 16.0
np.indices((3,3))/1
# Out:
# array([[[0., 0., 0.],
#         [1., 1., 1.],
#         [2., 2., 2.]],
#
#        [[0., 1., 2.],
#         [0., 1., 2.],
#         [0., 1., 2.]]])

# %%
import matplotlib.pyplot as plt
import numpy as np

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import


def midpoints(x):
    sl = ()
    for i in range(x.ndim):
        x = (x[sl + np.index_exp[:-1]] + x[sl + np.index_exp[1:]]) / 2.0
        sl += np.index_exp[:]
    return x

# prepare some coordinates, and attach rgb values to each
r, g, b = np.indices((17, 17, 17)) / 16.0
rc = midpoints(r)
gc = midpoints(g)
bc = midpoints(b)

# define a sphere about [0.5, 0.5, 0.5]
sphere = (rc - 0.5)**2 + (gc - 0.5)**2 + (bc - 0.5)**2 < 0.5**2

# combine the color components
colors = np.zeros(sphere.shape + (3,))
colors[..., 0] = rc
colors[..., 1] = gc
colors[..., 2] = bc

# and plot everything
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.voxels(r, g, b, sphere,
          facecolors=colors,
          edgecolors=np.clip(2*colors - 0.5, 0, 1),  # brighter
          linewidth=0.5)
ax.set(xlabel='r', ylabel='g', zlabel='b')

plt.show()

# %%
fig = go.Figure(data=[go.Surface(z=Z)])

fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.show()

# %%
import bqplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-18d327bfc849> in <module>
# ----> 1 import bqplot
#
# ModuleNotFoundError: No module named 'bqplot'

# %%
import plotly.graph_objects as go
fig = go.Figure(
    data=[go.Bar(y=[2, 1, 3])],
    layout_title_text="A Figure Displaying Itself"
)
fig

# %%
import plotly.graph_objects as go
fig = go.Figure(
    data=[go.Bar(y=[2, 1, 3])],
    layout_title_text="A Figure Displayed with fig.show()"
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-26-8ef27ab55239> in <module>
#       4     layout_title_text="A Figure Displayed with fig.show()"
#       5 )
# ----> 6 fig.show()
#
# ~/miniconda3/lib/python3.7/site-packages/plotly/basedatatypes.py in show(self, *args, **kwargs)
#    2656         import plotly.io as pio
#    2657
# -> 2658         return pio.show(self, *args, **kwargs)
#    2659
#    2660     def to_json(self, *args, **kwargs):
#
# ~/miniconda3/lib/python3.7/site-packages/plotly/io/_renderers.py in show(fig, renderer, validate, **kwargs)
#     389
#     390     # external renderers
# --> 391     renderers._perform_external_rendering(fig_dict, renderers_string=renderer, **kwargs)
#     392
#     393
#
# ~/miniconda3/lib/python3.7/site-packages/plotly/io/_renderers.py in _perform_external_rendering(self, fig_dict, renderers_string, **kwargs)
#     338                         setattr(renderer, k, v)
#     339
# --> 340                 renderer.render(fig_dict)
#     341
#     342
#
# ~/miniconda3/lib/python3.7/site-packages/plotly/io/_base_renderers.py in render(self, fig_dict)
#     729             validate=False,
#     730         )
# --> 731         open_html_in_browser(html, self.using, self.new, self.autoraise)
#     732
#     733
#
# ~/miniconda3/lib/python3.7/site-packages/plotly/io/_base_renderers.py in open_html_in_browser(html, using, new, autoraise)
#     674
#     675     server = HTTPServer(("127.0.0.1", 0), OneShotRequestHandler)
# --> 676     webbrowser.get(using).open(
#     677         "http://127.0.0.1:%s" % server.server_port, new=new, autoraise=autoraise
#     678     )
#
# ~/miniconda3/lib/python3.7/webbrowser.py in get(using)
#      63             elif command[0] is not None:
#      64                 return command[0]()
# ---> 65     raise Error("could not locate runnable browser")
#      66
#      67 # Please note: the following definition hides a builtin function.
#
# Error: could not locate runnable browser

# %%
import plotly.io as pio
pio.renderers
# Out:
# Renderers configuration
# -----------------------
#     Default renderer: 'nteract'
#     Available renderers:
#         ['plotly_mimetype', 'jupyterlab', 'nteract', 'vscode',
#          'notebook', 'notebook_connected', 'kaggle', 'azure', 'colab',
#          'cocalc', 'databricks', 'json', 'png', 'jpeg', 'jpg', 'svg',
#          'pdf', 'browser', 'firefox', 'chrome', 'chromium', 'iframe',
#          'iframe_connected', 'sphinx_gallery']

# %%
np.linalg.norm(vec2, ord=2)
# Out:
# 1.7320508075688772
