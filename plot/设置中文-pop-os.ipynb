# %% [markdown]
# matplotlib字体目录：/site-packages/matplotlib/mpl-data/fonts/ttf/
# 不支持ttc格式字体文件，譬如放入微软雅黑字体文件msyh.ttf

# %%
from matplotlib.font_manager import _rebuild
_rebuild()#重新创建字体索引列表
import matplotlib as mpl
# mpl.rcParams['font.family']=['Microsoft YaHei'] # windows

mpl.rcParams['font.family']=['simhei'] # linux

# %%
#或者修改/site-packages/matplotlib/mpl-data/matplotlibrc文件中的'font.family'字段
x = np.linspace(0,10,100)
plt.title('中文标题')
plt.plot(x,np.sin(x))
plt.show()
# Out:
# Text(0.5, 1.0, '中文标题')
